# %% [markdown]
# ## PERFORMANCE OF EMPLOYEE
# ### importing libraires

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### importing libraires

# %%
df=pd.read_excel("INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8 (2).xls")

# %% [markdown]
# ### data preprocess

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %%
df.shape
# Out:
# (1200, 28)

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %% [markdown]
# ## Data exploratory

# %%
Dif_depart=df.iloc[:,[5,-1]]
Dif_depart.head()
# Out:
#      EmpDepartment  PerformanceRating
# 0            Sales                  3
# 1            Sales                  3
# 2            Sales                  4
# 3  Human Resources                  3
# 4            Sales                  3

# %%
a=pd.crosstab(df.EmpDepartment, df.PerformanceRating)
a
# Out:
# PerformanceRating        2    3   4
# EmpDepartment
# Data Science             1   17   2
# Development             13  304  44
# Finance                 15   30   4
# Human Resources         10   38   6
# Research & Development  68  234  41
# Sales                   87  251  35

# %% [markdown]
# #### Finding correlation to get Important Factors effecting employee performance

# %%
updated_df=df
df_corr=updated_df.corr()

# %% [markdown]
# ####  Sorting the correlation out put, to get Top 3 Important Factors effecting employee performance

# %%
df_corr.sort_values('PerformanceRating',ascending=False,inplace=True)
df_corr.iloc[:,[-1]].head()
# Out:
#                             PerformanceRating
# PerformanceRating                    1.000000
# EmpEnvironmentSatisfaction           0.395561
# EmpLastSalaryHikePercent             0.333722
# EmpWorkLifeBalance                   0.124429
# NumCompaniesWorked                   0.020980

# %%
print("unique sets in Environment Satisfaction= ",df.EmpEnvironmentSatisfaction.unique())
print("unique sets in Last Salary Hike in Percentage (%)=  ",df.EmpLastSalaryHikePercent.unique())
print("unique sets in Work Life Balance=  ",df.EmpWorkLifeBalance.unique())
# Out:
# unique sets in Environment Satisfaction=  [4 2 1 3]
# unique sets in Last Salary Hike in Percentage (%)=   [12 21 15 14 13 23 11 20 19 17 18 22 16 24 25]
# unique sets in Work Life Balance=   [2 3 4 1]

# %% [markdown]
# Environment Satisfaction <br>
#     1 'Low'<br>
# 	2 'Medium'<br>
# 	3 'High'<br>
# 	4 'Very High'<br>
# Work Life Balance<br>
#     1 'Bad'<br>
# 	2 'Good'<br>
# 	3 'Better'<br>
# 	4 'Best'<br>

# %%
EnvSatisfaction=pd.crosstab(df.EmpEnvironmentSatisfaction, df.PerformanceRating)
EnvSatisfaction
# Out:
# PerformanceRating            2    3   4
# EmpEnvironmentSatisfaction
# 1                           90  127  13
# 2                           98  130  14
# 3                            3  310  54
# 4                            3  307  51

# %%
EnvSalaryhike=pd.crosstab(df.EmpLastSalaryHikePercent, df.PerformanceRating)
EnvSalaryhike
# Out:
# PerformanceRating          2    3   4
# EmpLastSalaryHikePercent
# 11                        28  140   1
# 12                        30  123   2
# 13                        27  138   3
# 14                        28  140   4
# 15                        11   67   4
# 16                        12   54   2
# 17                         9   55   3
# 18                        10   63   0
# 19                        10   51   2
# 20                         9   14  27
# 21                         4    6  24
# 22                         7   13  27
# 23                         4    2  15
# 24                         2    5  11
# 25                         3    3   7

# %%
WorkLifeBal=pd.crosstab(df.EmpWorkLifeBalance, df.PerformanceRating)
WorkLifeBal
# Out:
# PerformanceRating     2    3   4
# EmpWorkLifeBalance
# 1                    16   48   0
# 2                    51  216  27
# 3                   115  533  79
# 4                    12   77  26

# %% [markdown]
# #### Creating a dummies Sub_set Data Frame

# %%
df_dummies=pd.get_dummies(df)
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %%
df_dummies.to_csv("df_dummies.csv")
